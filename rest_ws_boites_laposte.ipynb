# %% [markdown]
# <a href="https://colab.research.google.com/github/Didier-Lebourgeois/colab/blob/main/rest_ws_boites_laposte.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Retrouver les boîtes postales d'une ville avec leur localisation depuis les webservices de la poste

# %%
#@title
import requests
import pandas as pd
import re

# %%
#@title Paramètres de recherche
code_postal = "78100" #@param {type:"string"}
nom_commune = "SAINT GERMAIN EN LAYE" #@param {type:"string"}

# %%
nom_commune = nom_commune.replace(' ','+')

# %%
url = "https://datanova.laposte.fr/api/records/1.0/search/\
# ?dataset=laposte_boiterue&q=&lang=fr&rows=50&facet=co_postal&\
facet=lb_com&refine.co_postal={0}&refine.lb_com={1}".format(
    code_postal,nom_commune
)

# %%
dataset = requests.get(url)

# %%
df = pd.json_normalize(dataset.json(),record_path="records")

# %%
df
# Out:
#            datasetid  ... fields.lb_extension
# 0   laposte_boiterue  ...                 NaN
# 1   laposte_boiterue  ...                 NaN
# 2   laposte_boiterue  ...                 NaN
# 3   laposte_boiterue  ...                 NaN
# 4   laposte_boiterue  ...                 NaN
# 5   laposte_boiterue  ...                 BIS
# 6   laposte_boiterue  ...                 NaN
# 7   laposte_boiterue  ...                 NaN
# 8   laposte_boiterue  ...                 NaN
# 9   laposte_boiterue  ...                 NaN
# 10  laposte_boiterue  ...                 NaN
# 11  laposte_boiterue  ...                 NaN
# 12  laposte_boiterue  ...                 NaN
# 13  laposte_boiterue  ...                 NaN
# 14  laposte_boiterue  ...                 NaN
# 15  laposte_boiterue  ...                 NaN
# 16  laposte_boiterue  ...                 NaN
# 17  laposte_boiterue  ...                 NaN
# 18  laposte_boiterue  ...                 NaN
# 19  laposte_boiterue  ...                 NaN
# 20  laposte_boiterue  ...                 NaN
# 21  laposte_boiterue  ...                 NaN
# 22  laposte_boiterue  ...                 NaN
# 23  laposte_boiterue  ...                 NaN
# 24  laposte_boiterue  ...                 NaN
# 25  laposte_boiterue  ...                 NaN
# 26  laposte_boiterue  ...                 NaN
# 27  laposte_boiterue  ...                 NaN
# 28  laposte_boiterue  ...                 NaN
# 29  laposte_boiterue  ...                 NaN
# 30  laposte_boiterue  ...                 NaN
# 31  laposte_boiterue  ...                 NaN
# 32  laposte_boiterue  ...                 NaN
# 33  laposte_boiterue  ...                 NaN
# 34  laposte_boiterue  ...                   B
# 35  laposte_boiterue  ...                 NaN
# 36  laposte_boiterue  ...                 NaN
# 37  laposte_boiterue  ...                 NaN
# 38  laposte_boiterue  ...                 NaN
# 39  laposte_boiterue  ...                 NaN
# 40  laposte_boiterue  ...                 NaN
# 41  laposte_boiterue  ...                 NaN
#
# [42 rows x 17 columns]
